# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
import numpy as np

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# #### Seaborn is a data visualization library based on matplotlib.It provides a highlevel interface for drawing attractive and informative statistical graphics...

# %% [markdown]
# ### Distribution Plots

# %% [markdown]
# #### 1. dist plot

# %%
sns.distplot(x = df['total_bill'],color = 'black',bins = 10)
# Out:
# C:\Users\chand\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# #### 2. Joint Plot

# %%
sns.jointplot(y = 'tip',x = 'total_bill',data = df,kind = 'reg')

# %%
sns.jointplot(y = 'tip',x = 'total_bill',data = df,kind = 'hex',color = 'darkcyan')

# %%
sns.jointplot(y = 'tip',x = 'total_bill',data = df,kind = 'kde',color = 'darkcyan')

# %% [markdown]
# #### 3. Pair Plot

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue = 'sex',palette = 'Blues')

# %% [markdown]
# #### 4. Rug Plot

# %%
sns.rugplot(df['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.set_style('darkgrid')
plt.figure(figsize = (8,6))
sns.jointplot(y = 'tip',x = 'total_bill',data = df,kind = 'kde',color = 'darkcyan')

# %%
sns.set_style('darkgrid')
plt.figure(figsize = (8,6))
sns.jointplot(y = 'tip',x = 'total_bill',data = df,color = 'darkcyan')

# %%
sns.set_style('darkgrid')
plt.figure(figsize = (8,6))
sns.jointplot(y = 'tip',x = 'total_bill',data = df,kind = 'reg',color = 'darkcyan')

# %%
sns.set_style('darkgrid')
plt.figure(figsize = (8,6))
sns.jointplot(y = 'tip',x = 'total_bill',data = df,kind = 'reg',color = 'darkcyan')
sns.despine(left = True)

# %%
sns.set_style('darkgrid')
plt.figure(figsize = (8,6))
sns.jointplot(y = 'tip',x = 'total_bill',data = df,kind = 'reg',color = 'darkcyan')
sns.despine(left = False)
